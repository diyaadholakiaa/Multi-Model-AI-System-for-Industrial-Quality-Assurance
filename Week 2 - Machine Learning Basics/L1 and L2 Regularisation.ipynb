# %% [markdown]
# # L1 and L2 regularisation
# When a model becomes too complex, it may overfit the training data—it memorizes noise instead of learning the underlying pattern. Regularization adds a penalty to the loss function, discouraging large weights and helping the model generalize better to unseen data.
#
# L1 is like a strict teacher who says: If a feature isn't helping much, get rid of it completely, i.e. it makes irrelevant weights zero
#
# L2 is a gentler teacher who says: Don't remove features. Just reduce everyone's importance a little, i.e. it reduces all weights

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# tells python to ignore all warnings

# %%
dataset = pd.read_csv('data/Melbourne_housing_FULL.csv')

# %%
dataset.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
dataset.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %% [markdown]
# returns the number of unique values in each column

# %%
dataset.shape
# Out:
# (34857, 21)

# %% [markdown]
# dimensions of the dataframe (no. of rows, no. of columns)

# %%
dataset.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
# Some feature's missing values can be treated as zero (another class for NA values or absence of that feature)
# like 0 for Propertycount, Bedroom2 will refer to other class of NA values
# like 0 for Car feature will mean that there's no car parking feature with house
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
dataset[cols_to_fill_zero] = dataset[cols_to_fill_zero].fillna(0)

# other continuous features can be imputed with mean for faster results since our focus is on Reducing overfitting
# using Lasso and Ridge Regression
dataset['Landsize'] = dataset['Landsize'].fillna(dataset.Landsize.mean())
dataset['BuildingArea'] = dataset['BuildingArea'].fillna(dataset.BuildingArea.mean())

# %%
dataset.dropna(inplace=True)

# %%
dataset = pd.get_dummies(dataset, drop_first=True)

# %%
dataset.head()
# Out:
#     Rooms      Price  Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  \
# 2       2  1035000.0       2.5    3067.0       2.0       1.0  0.0     156.0
# 4       3  1465000.0       2.5    3067.0       3.0       2.0  0.0     134.0
# 6       4  1600000.0       2.5    3067.0       3.0       1.0  2.0     120.0
# 11      3  1876000.0       2.5    3067.0       4.0       2.0  0.0     245.0
# 14      2  1636000.0       2.5    3067.0       2.0       1.0  2.0     256.0
#
#     BuildingArea  YearBuilt  ...  CouncilArea_Wyndham City Council  \
# 2           79.0     1900.0  ...                             False
# 4          150.0     1900.0  ...                             False
# 6          142.0     2014.0  ...                             False
# 11         210.0     1910.0  ...                             False
# 14         107.0     1890.0  ...                             False
#
#     CouncilArea_Yarra City Council  CouncilArea_Yarra Ranges Shire Council  \
# ...

# %%
X = dataset.drop('Price', axis=1)
y = dataset['Price']

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(train_X, train_y)

# %%
reg.score(test_X, test_y)
# Out:
# 0.6033040135706051

# %%
reg.score(train_X, train_y)
# Out:
# 1.0

# %%
from sklearn import linear_model
lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(train_X, train_y)
# Out:
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(test_X, test_y)
# Out:
# 0.7250391871835353

# %%
lasso_reg.score(train_X, train_y)
# Out:
# 0.8905041651229756

# %%
from sklearn.linear_model import Ridge
ridge_reg= Ridge(alpha=50, max_iter=100, tol=0.1)
ridge_reg.fit(train_X, train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(test_X, test_y)
# Out:
# 0.7280762467229374

# %%
ridge_reg.score(train_X, train_y)
# Out:
# 0.7221305021912454
